# %% [markdown]
# <a href="https://colab.research.google.com/github/Hegrada/Wan2.2/blob/main/Wan2.2-notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Wan-Video/Wan2.2.git
# %cd Wan2.2
# Out:
# Cloning into 'Wan2.2'...
# remote: Enumerating objects: 219, done.
# remote: Counting objects: 100% (162/162), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 219 (delta 85), reused 49 (delta 49), pack-reused 57 (from 1)
# Receiving objects: 100% (219/219), 8.12 MiB | 29.58 MiB/s, done.
# Resolving deltas: 100% (86/86), done.
# /content/Wan2.2
